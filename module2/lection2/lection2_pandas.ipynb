# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
s1=pd.Series([22,23,24],name='ages')
s1
# Out:
# 0    22
# 1    23
# 2    24
# Name: ages, dtype: int64

# %%
s1.max()
# Out:
# 24

# %% [markdown]
# ##DataFrame##

# %%
df=pd.DataFrame({'names':['Danil','Egor','Olesya','Misha'], 'ages':[16,14,19,22]})
df
# Out:
#     names  ages
# 0   Danil    16
# 1    Egor    14
# 2  Olesya    19
# 3   Misha    22

# %%
df['names'][:2]
# Out:
# 0    Danil
# 1     Egor
# Name: names, dtype: object

# %%
titanic_data_frame=pd.read_csv('titanic.csv')
titanic_data_frame
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
fisrt_class_passengers=titanic_data_frame[titanic_data_frame['Pclass']==1]
fisrt_class_passengers
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
second_class_passengers=titanic_data_frame[titanic_data_frame['Pclass']==2]
second_class_passengers
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 17                   Williams, Mr. Charles Eugene    male   NaN      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# ...

# %%
fhird_class_passengers=titanic_data_frame[titanic_data_frame['Pclass']==3]
fhird_class_passengers
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
third_class_passengers=titanic_data_frame[titanic_data_frame['Pclass']==3]
third_class_passengers_survived=third_class_passengers[fhird_class_passengers['Survived']==True]
third_class_survived_precent=(len(third_class_passengers_survived)/len(third_class_passengers))*100
third_class_survived_precent
# Out:
# 24.236252545824847

# %%
first_class_passengers=titanic_data_frame[titanic_data_frame['Pclass']==1]
first_class_passengers_survived=first_class_passengers[first_class_passengers['Survived']==True]
first_class_survived_precent=(len(third_class_passengers_survived)/len(first_class_passengers))*100
first_class_survived_precent
# Out:
# 55.092592592592595

# %%
second_class_passengers=titanic_data_frame[titanic_data_frame['Pclass']==1]
second_class_passengers_survived=second_class_passengers[second_class_passengers['Survived']==True]
second_class_survived_precent=(len(second_class_passengers_survived)/len(second_class_passengers))*100
second_class_survived_precent
# Out:
# 62.96296296296296

# %%
len(third_class_passengers_survived[third_class_passengers_survived['Sex']=='female'])/len(third_class_passengers)*100
# Out:
# 14.663951120162933

# %%
titanic_data_frame.dropna(how='any')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data_frame.dropna(how='any')
survived=titanic_data_frame[titanic_data_frame['Survived']==True]
survived_precent=(len(survived)/len(titanic_data_frame))*100
survived_precent
# Out:
# 38.38383838383838

# %%
middle_age = titanic_data_frame['Age'].mean()
middle_age
# Out:
# 29.69911764705882

# %%
junior_survived = (len(titanic_data_frame[(titanic_data_frame['Survived']==True) & (titanic_data_frame['Age']<18)])/len(titanic_data_frame))*100

junior_surved
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 9             10         1       2       Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# 39            40         1       3               Nicola-Yarred, Miss. Jamila
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 830          831         1       3   Yasbeck, Mrs. Antoni (Selini Alexander)
# 831          832         1       2           Richards, Master. George Sibley
# 853          854         1       1                 Lines, Miss. Mary Conover
# 869          870         1       3           Johnson, Master. Harold Theodor
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
middle_survived = (len(titanic_data_frame[(titanic_data_frame['Survived']==True) & (titanic_data_frame['Age']>=18) & (titanic_data_frame['Age']<50) ])/len(titanic_data_frame))*100
middle_surved
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 21            22         1       2
# ..           ...       ...     ...
# 871          872         1       1
# 874          875         1       2
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
old_survived = (len(titanic_data_frame[(titanic_data_frame['Survived']==True) & (titanic_data_frame['Age']>=50)]) / len(titanic_data_frame)) * 100
old_survived
# Out:
# 3.0303030303030303

# %%
russian_population_by_years_first=pd.read_csv('russian_population_by_years.csv')
rp_data_frame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 russian_population_by_years_first=pd.read_csv('russian_population_by_years.csv')
# ----> 2 rp_data_frame
#
# NameError: name 'rp_data_frame' is not defined

# %%
#создадим новую структуру data frame
# Регион-1990-1991-...
# Адыгея-2640419.0-...
years = list(range(1990, 2020))
colum = ['Region']
new_rp_data_frame= pd.DataFrame(colum)
for i in years:
    new_rp_data_frame[i]
new_rp_data_frame п

# %%
import numpy as np
#создадим новую структуру data frame
# Регион-1990-1991-...
# Адыгея-2640419.0-...
years = list(range(1990, 2020))
region=np.array(rp_data_frame['Адыгея'].values)
population=rp_data_frame['434788.0'].values
region
#population
# Out:
# array(['Алтайский край', 'Амурская область', 'Архангельская область', ...,
#        'Якутия', 'Ямало-Ненецкий автономный округ', 'Ярославская область'],
#       dtype=object)

# %%
new_rp_data_frame={'region':[region]}
# for year in years:
#     for i in population:
#         new_rp_data_frame[str(year)] = i
new_rp_data_frame
# Out:
# {'region': [array(['Алтайский край', 'Амурская область', 'Архангельская область', ...,
#          'Якутия', 'Ямало-Ненецкий автономный округ', 'Ярославская область'],
#         dtype=object)]}

# %%
import pandas as pd 
import numpy as np

# %%
def get_first_variant(df):
    additionally_data=[]
    for i in df.columns:
        additionally_data.append(i)
    return pd.DataFrame({'Year':[int(additionally_data[0]),*df['1990']],'Region':[str(additionally_data[1]),*df['Адыгея']],'Population':[float(additionally_data[2]),*df['434788.0']]})
def get_second_variant(df):
    years=[str(i) for i in df['Year'].unique()]
    regions=[str(i) for i in df['Region'].unique()]
    pre_data_frame={}
    pre_data_frame['Region']=[]
    for k in years:
        pre_data_frame[str(k)]=[]
    for i in regions:
        pre_data_frame['Region'].append(i)
        for j in years:
            try:
                pre_data_frame[str(j)].append(float(df[(df['Region']==i) & (df['Year']==int(j))]['Population']))
            except:
                pre_data_frame[str(j)].append(float(np.nan))
    return pd.DataFrame(pre_data_frame)
ugly_data_frame=pd.read_csv('russian_population_by_years.csv')
ugly_data_frame.dtypes
get_first_variant(ugly_data_frame).to_csv('russian_population_by_years_first.csv')
first_df=pd.read_csv('russian_population_by_years_first.csv')
get_second_variant(first_df).to_csv('russian_population_by_years_second.csv')

# %%
russian_population_by_years_second=pd.read_csv('russian_population_by_years_second.csv')
russian_population_by_years_second
# Out:
#     Unnamed: 0                           Region       1990       1991  \
# 0            0                           Адыгея   434788.0   436598.0
# 1            1                   Алтайский край  2640419.0  2653818.0
# 2            2                 Амурская область  1055337.0  1054267.0
# 3            3            Архангельская область  1523509.0  1517293.0
# 4            4             Астраханская область   997516.0  1001044.0
# ..         ...                              ...        ...        ...
# 80          80                          Чувашия  1337182.0  1339822.0
# 81          81       Чукотский автономный округ   162135.0   158056.0
# 82          82                           Якутия  1111480.0  1118983.0
# 83          83  Ямало-Ненецкий автономный округ   489161.0   488577.0
# 84          84              Ярославская область  1472126.0  1473837.0
#
#          1992       1993       1994       1995       1996       1997  ...  \
# ...

# %%
df=pd.read_csv('russian_population_by_years_second.csv')
df_1990_top = df.sort_values('1990', ascending=False).head(3)
df_1990_end = df.sort_values('1990', ascending=False).tail(3)
df_2019_top = df.sort_values('2019', ascending=False).head(3)
df_2019_end = df.sort_values('2019', ascending=False).tail(3)
df_1990_top
df_1990_end
df_2019_top
df_2019_end
# Out:
#     Unnamed: 0                      Region      1990      1991      1992  \
# 36          36         Магаданская область  390276.0  384525.0  365311.0
# 81          81  Чукотский автономный округ  162135.0  158056.0  147930.0
# 42          42   Ненецкий автономный округ   51993.0   51667.0   50245.0
#
#         1993      1994      1995      1996      1997  ...      2010      2011  \
# 36  323673.0  300157.0  266883.0  240215.0  229148.0  ...  159002.0  156534.0
# 81  124351.0  111422.0   95769.0   84451.0   77917.0  ...   51179.0   50346.0
# 42   48235.0   46504.0   44526.0   43367.0   42549.0  ...   42115.0   42104.0
#
#         2012      2013      2014      2015      2016      2017      2018  \
# 36  154485.0  152358.0  150312.0  148071.0  146345.0  145570.0  144091.0
# 81   50988.0   50780.0   50555.0   50540.0   50157.0   49822.0   49348.0
# 42   42437.0   42789.0   43025.0   43373.0   43838.0   43937.0   43997.0
#
#         2019
# 36  141234.0
# 81   49663.0
# 42   43829.0
#
# ...

# %%
russian_population_by_years_first=pd.read_csv('russian_population_by_years_first.csv')
df_1=russian_population_by_years_first

# %%
df_1 = df_1.sort_values('Year', ascending=True)#в порядке возрастания
df_1990 = df_1[df_1['Year'] == 1990]
df_1990
# Out:
#     Unnamed: 0  Year                           Region  Population
# 0            0  1990                           Адыгея    434788.0
# 42          42  1990        Ненецкий автономный округ     51993.0
# 2            2  1990                 Амурская область   1055337.0
# 3            3  1990            Архангельская область   1523509.0
# 4            4  1990             Астраханская область    997516.0
# ..         ...   ...                              ...         ...
# 81          81  1990       Чукотский автономный округ    162135.0
# 82          82  1990                           Якутия   1111480.0
# 83          83  1990  Ямало-Ненецкий автономный округ    489161.0
# 84          84  1990              Ярославская область   1472126.0
# 44          44  1990             Новгородская область    753369.0
#
# [85 rows x 4 columns]

# %%
df=pd.read_csv('russian_population_by_years_first.csv')

# Создание пустого списка для хранения данных об изменении численности населения
population_growth = []

# Проход по строкам DataFrame
for i in range(1, len(df)):
    # Расчет изменения численности населения и добавление в список
    growth = df.iloc[i]['Population'] - df.iloc[i-1]['Population']
    population_growth.append(growth)

# Нахождение индекса года с максимальным приростом численности населения

# Получение года с максимальным приростом
max_growth_year = df.iloc[population_growth.index(max(population_growth))]['Year']


# Вывод года с максимальным приростом
print("Год с максимальным приростом численности населения:", max_growth_year," - ",max(population_growth))
# Out:
# Год с максимальным приростом численности населения: 2019  -  11819775.0

# %%
df=pd.read_csv('russian_population_by_years_first.csv')

population_growth = []

for i in range(1, len(df)):
    growth = df.iloc[i]['Population'] - df.iloc[i-1]['Population']
    population_growth.append(growth)

max_growth_year = df.iloc[population_growth.index(max(population_growth))]['Year']

print("Год с максимальным приростом численности населения:", max_growth_year," - ",max(population_growth))
# Out:
# Год с максимальным приростом численности населения: 2019  -  11819775.0

# %%
df=pd.read_csv('russian_population_by_years_first.csv')
df_growth=df[(df['Year'] >= 1990) & (df['Year'] <= 2019)]
df_growth['Population_Growth'] = df_growth['Population'].diff()
df_growth
# Out:
#       Unnamed: 0  Year                           Region  Population  \
# 0              0  1990                           Адыгея    434788.0
# 1              1  1990                   Алтайский край   2640419.0
# 2              2  1990                 Амурская область   1055337.0
# 3              3  1990            Архангельская область   1523509.0
# 4              4  1990             Астраханская область    997516.0
# ...          ...   ...                              ...         ...
# 2535        2535  2019                          Чувашия   1223395.0
# 2536        2536  2019       Чукотский автономный округ     49663.0
# 2537        2537  2019                           Якутия    967009.0
# 2538        2538  2019  Ямало-Ненецкий автономный округ    541479.0
# 2539        2539  2019              Ярославская область   1259612.0
#
#       Population_Growth
# 0                   NaN
# 1             2205631.0
# 2            -1585082.0
# 3              468172.0
# ...

# %%
df=pd.read_csv('russian_population_by_years_first.csv')
df_growth=df[df['Year'] >= 2018]
df_growth['Population_Growth'] = df_growth['Population'].diff()
df_growth.head(3)
df_growth.tail(3)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9888\1973382034.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_growth['Population_Growth'] = df_growth['Population'].diff()
#       Unnamed: 0  Year                           Region  Population  \
# 2537        2537  2019                           Якутия    967009.0
# 2538        2538  2019  Ямало-Ненецкий автономный округ    541479.0
# 2539        2539  2019              Ярославская область   1259612.0
#
#       Population_Growth
# 2537           917346.0
# 2538          -425530.0
# 2539           718133.0

# %%
df = pd.read_csv('russian_population_by_years_first.csv')
df_growth = df[df['Year'] >= 2018].copy()
df_growth['Population_Growth'] = df_growth['Population'].diff()
df_growth.head(3)
df_growth.tail(3)
# Out:
#       Unnamed: 0  Year                           Region  Population  \
# 2537        2537  2019                           Якутия    967009.0
# 2538        2538  2019  Ямало-Ненецкий автономный округ    541479.0
# 2539        2539  2019              Ярославская область   1259612.0
#
#       Population_Growth
# 2537           917346.0
# 2538          -425530.0
# 2539           718133.0

# %%
df_growth_1990_2019 = df[(df['Year'] >= 1990) & (df['Year'] <= 2019)].copy()
df_growth_1990_2019['Population_Growth'] = df_growth_1990_2019['Population'].diff()
df_growth_1990_2019.head(3)
df_growth_1990_2019.tail(3)
# Out:
#       Unnamed: 0  Year                           Region  Population  \
# 2537        2537  2019                           Якутия    967009.0
# 2538        2538  2019  Ямало-Ненецкий автономный округ    541479.0
# 2539        2539  2019              Ярославская область   1259612.0
#
#       Population_Growth
# 2537           917346.0
# 2538          -425530.0
# 2539           718133.0

# %%
df_growth_2000_2019 = df[(df['Year'] >= 2000) & (df['Year'] <= 2019)].copy()
df_growth_2000_2019['Population_Growth'] = df_growth_2000_2019['Population'].diff()
df_growth_2000_2019.head(3)
df_growth_2000_2019.tail(3)
